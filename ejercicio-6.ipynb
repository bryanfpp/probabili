# %% [markdown]
# # EJERCICIO 6
#
#
#  Calcular:
#
#  A)9!
#
#  B)3! × 5!
#
#  C)15C5
#
#  D)12P7
#
#  E)5C0 + 5C1 + 5C2
#
#  F)6P4 + 6P5 + 6P6
#
#  G)4C0 × 3C2 + 4C1 × 3C1

# %%
from math import comb

resultado_1 = comb(5, 0)
print(resultado_1)
resultado_2 = comb(5, 1)
print(resultado_2)
resultado_3 = comb(5, 2)
print(resultado_3)

resultado_E = resultado_1 + resultado_2 + resultado_3
print(resultado_E)
# Out:
# 1
# 5
# 10
# 16

# %%
from math import perm
resultado_1 = perm(6, 4)
print(resultado_1)
resultado_2 = perm(6, 5)
print(resultado_2)
resultado_3 = perm(6, 6)
print(resultado_3)

resultado_F = resultado_1 + resultado_2 + resultado_3
print(resultado_F)
# Out:
# 360
# 720
# 720
# 1800

# %%
from math import comb
resultado_1 = comb(3, 2)
print(resultado_1)
resultado_2 = comb(4, 1)
print(resultado_2)
resultado_3 = comb(3, 1)
print(resultado_3)

resultado_G = resultado_1 + resultado_2 + resultado_3
print(resultado_G)
# Out:
# 3
# 4
# 3
# 10
